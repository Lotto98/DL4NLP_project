# %%
import json
import matplotlib.pyplot as plt

with open('output/metrics.json', 'r') as f:
    metrics = []
    for line in f:
        metrics.append(json.loads(line))
        
with open('output/metrics_val.json', 'r') as f:
    metrics_val = []
    for line in f:
        metrics_val.append(json.loads(line))

# %%
metrics[0].keys()
# Out:
# dict_keys(['data_time', 'iteration', 'loss_bbox', 'loss_ce', 'loss_giou', 'lr', 'rank_data_time', 'total_loss'])

# %%
total_loss = [metric.get('total_loss', None) for metric in metrics]
iterations = [metric.get('iteration', None) for metric in metrics]

plt.plot(iterations[::19], total_loss[::19])
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Train Loss every 20 Iteration')
plt.show()

plt.plot(iterations, total_loss)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Train Loss every Iteration')
plt.show()

# %%
#sum total loss every tot iterations
epoch_size = 2093
loss_per_epoch = [sum(total_loss[i:i+epoch_size]) for i in range(0, len(total_loss), epoch_size if epoch_size > 0 else 1)]
epochs = [i for i in range(0, len(loss_per_epoch))]

print(loss_per_epoch)

plt.plot(epochs, loss_per_epoch)
plt.xlabel('Epoch')
plt.ylabel('Epoch Loss')
plt.title('Train Loss per Epoch')
plt.show()
# Out:
# [11869.924100011587, 10968.861389547586, 10965.579335942864, 11043.113605991006, 11069.26602679491, 11007.52834405005, 436.12333783507347]

# %%
total_loss_val = [metric.get('total_loss', None) for metric in metrics_val]
iterations_val = [e for e in range(0, len(total_loss_val))]

epoch_size = 3491
loss_per_epoch = [sum(total_loss_val[i:i+epoch_size]) for i in range(0, len(total_loss_val), epoch_size)]
epochs = [i for i in range(0, len(loss_per_epoch))]

print(loss_per_epoch)

plt.plot(epochs, loss_per_epoch)
plt.xlabel('Epoch')
plt.ylabel('Epoch Loss')
plt.title('Epoch Loss over Epochs')
plt.show()
# Out:
# [19064.695017144084, 19030.397121647373, 19063.351530916872, 19202.745724638702, 19190.321840624616, 18975.602841954456]

# %%
#plot lr over iterations
lr = [metric.get('lr', None) for metric in metrics]
plt.plot(iterations, lr)

#add line at iteration 1000
plt.axvline(x=1800, color='r', linestyle='--')

# %%
lr[2159//20]
# Out:
# 5.207166746297181e-08

# %%
print(lr)
# Out:
# [1e-09, 1.47730530339226e-09, 1.95461060678452e-09, 2.43191591017678e-09, 2.909221213569039e-09, 3.386526516961299e-09, 3.863831820353559e-09, 4.341137123745819e-09, 4.818442427138079e-09, 5.2957477305303395e-09, 5.7730530339225985e-09, 6.250358337314859e-09, 6.727663640707119e-09, 7.204968944099379e-09, 7.682274247491639e-09, 8.159579550883898e-09, 8.636884854276157e-09, 9.11419015766842e-09, 9.591495461060677e-09, 1.0068800764452937e-08, 1.0546106067845198e-08, 1.1023411371237457e-08, 1.1500716674629718e-08, 1.1978021978021977e-08, 1.2455327281414237e-08, 1.2932632584806496e-08, 1.3409937888198757e-08, 1.3887243191591016e-08, 1.4364548494983277e-08, 1.4841853798375538e-08, 1.5319159101767797e-08, 1.5796464405160056e-08, 1.6273769708552318e-08, 1.6751075011944577e-08, 1.7228380315336836e-08, 1.7705685618729095e-08, 1.8182990922121357e-08, 1.8660296225513617e-08, 1.9137601528905872e-08, 1.9614906832298138e-08, 2.0092212135690394e-08, 2.0569517439082653e-08, 2.1046822742474918e-08, 2.1524