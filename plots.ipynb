# %%
import json
import matplotlib.pyplot as plt

with open('output/metrics.json', 'r') as f:
    metrics = []
    for line in f:
        metrics.append(json.loads(line))
        
with open('output/metrics_val.json', 'r') as f:
    metrics_val = []
    for line in f:
        metrics_val.append(json.loads(line))

# %%
metrics[0].keys()
# Out:
# dict_keys(['data_time', 'iteration', 'loss_bbox', 'loss_ce', 'loss_giou', 'lr', 'rank_data_time', 'total_loss'])

# %%
total_loss = [metric.get('total_loss', None) for metric in metrics]
iterations = [metric.get('iteration', None) for metric in metrics]

plt.plot(iterations, total_loss)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Train Loss per Iteration')
plt.show()

# %%
#sum total loss every tot iterations
epoch_size = 1000
loss_per_epoch = [sum(total_loss[i:i+epoch_size]) for i in range(0, len(total_loss), epoch_size if epoch_size > 0 else 1)]
epochs = [i for i in range(0, len(loss_per_epoch))]

print(loss_per_epoch)

plt.plot(epochs, loss_per_epoch)
plt.xlabel('Epoch')
plt.ylabel('Epoch Loss')
plt.title('Train Loss per Epoch')
plt.show()
# Out:
# [7481.2970597893, 5324.208893045783, 5353.579086378217, 5305.052466973662, 5512.001995012164, 5673.506256654859, 5402.03485737741, 1405.030982941389]

# %%
total_loss_val = [metric.get('total_loss', None) for metric in metrics_val]
iterations_val = [e for e in range(0, len(total_loss_val))]

epoch_size = 3505
loss_per_epoch = [sum(total_loss_val[i:i+epoch_size]) for i in range(0, len(total_loss_val), epoch_size)]
epochs = [i for i in range(1, len(loss_per_epoch)+1)]

plt.plot(loss_per_epoch, epochs)
plt.xlabel('Epoch')
plt.ylabel('Epoch Loss')
plt.title('Epoch Loss over Epochs')
plt.show()

# %%
loss_per_epoch
# Out:
# [10056.840453393757]

# %%
loss_per_epoch
# Out:
# [10056.840453393757]

# %%
#plot lr over iterations
lr = [metric.get('lr', None) for metric in metrics]
plt.plot(iterations, lr)

#add line at iteration 1000
plt.axvline(x=1800, color='r', linestyle='--')

# %%
lr[2159//20]
# Out:
# 8.293463427947598e-09

# %%
print(lr)
# Out:
# [1e-09, 1.0681632096069868e-09, 1.1363264192139738e-09, 1.2044896288209608e-09, 1.2726528384279476e-09, 1.3408160480349343e-09, 1.4089792576419215e-09, 1.4771424672489085e-09, 1.545305676855895e-09, 1.613468886462882e-09, 1.6816320960698688e-09, 1.7497953056768558e-09, 1.8179585152838428e-09, 1.8861217248908294e-09, 1.9542849344978163e-09, 2.0224481441048037e-09, 2.0906113537117903e-09, 2.1587745633187773e-09, 2.2269377729257643e-09, 2.295100982532751e-09, 2.363264192139738e-09, 2.4314274017467248e-09, 2.4995906113537118e-09, 2.5677538209606983e-09, 2.6359170305676853e-09, 2.7040802401746723e-09, 2.772243449781659e-09, 2.8404066593886462e-09, 2.9085698689956332e-09, 2.9767330786026194e-09, 3.044896288209607e-09, 3.1130594978165933e-09, 3.1812227074235807e-09, 3.2493859170305677e-09, 3.3175491266375547e-09, 3.3857123362445417e-09, 3.4538755458515282e-09, 3.522038755458515e-09, 3.590201965065502e-09, 3.658365174672489e-09, 3.726528384279476e-09, 3.794691593886462e-09, 3.86285480349345e-09, 3.931018013100437e-09, 3.999181222707424e-09,